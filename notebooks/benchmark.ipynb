# %% [markdown]
# ## Бенчмарк для тестирования правильности ответов получаемых из RAG

# %% [markdown]
# ### Методология
#
#  Бенчмарк тестирует качество ответов RAG-системы путем сравнения с эталонными ответами:
#
# 1. **Загрузка вопросов** - из YAML файла с эталонными ответами
# 2. **Генерация ответов** - через RAG-систему с использованием Qdrant + OpenAI
# 3. **Оценка корректности** - автоматическое сравнение с эталоном через GPT-4
# 4. **Метрики** - подсчет процента правильных, частично правильных и неправильных ответов
# 5. **Логирование** - сохранение результатов в JSON для анализа

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct
from openai import OpenAI
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os

# %%
# Settings 
QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
COLLECTION_NAME = os.getenv("COLLECTION_NAME")

# Client Initialization
client = OpenAI(api_key=OPENAI_API_KEY)
qdrant = QdrantClient(url=QDRANT_URL, api_key=QDRANT_API_KEY)

# %%
def ask_qdrant(question):
    """
    Выполняет поиск релевантной информации в векторной базе данных Qdrant и генерирует ответ на вопрос.
    
    Функция принимает вопрос пользователя, создает его векторное представление с помощью OpenAI embeddings,
    выполняет семантический поиск в коллекции Qdrant, собирает найденные фрагменты текста в контекст
    и генерирует ответ с помощью GPT-4o-mini на основе только найденной информации.
    
    Args:
        question (str): Вопрос пользователя на русском языке
        
    Returns:
        str: Сгенерированный ответ на основе найденных в базе данных фрагментов,
             включающий ссылки на источники информации
             
    Example:
        >>> answer = ask_qdrant("Что такое лептоспироз?")
        >>> print(answer)
        'Лептоспироз — это инфекционная болезнь...'
    """
    query_embedding = client.embeddings.create(
        model="text-embedding-3-small",
        input=question
    ).data[0].embedding

    # Используем новый API query_points
    results = qdrant.query_points(
        collection_name=COLLECTION_NAME,
        query=query_embedding,
        limit=40
    )

    # Собираем контекст и источники
    context_parts = []
    sources = set()
    
    for point in results.points:
        context_parts.append(point.payload["text"])
        filename = point.payload.get("filename", "Unknown")
        page = point.payload.get("page_number", -1)
        sources.add(f"{filename} (стр. {page})" if page != -1 else filename)

    context = "\n\n".join(context_parts)

    prompt = f"""Системное сообщение:
                Ты — опытный ветеринарный консультант. У тебя есть доступ к базе знаний — текстам, документам и фрагментам, которые были извлечены по запросу пользователя.  
                Когда пользователь задаёт вопрос, ты:  
                - извлекаешь релевантные фрагменты из этой базы;  
                - используешь **только** информацию, содержащуюся в этих фрагментах;  
                - **не** добавляешь никаких внешних знаний или догадок за пределами базы;  
                - если база не содержит достаточной информации для ответа — честно говоришь об этом.

                Инструкции к ответу:  
                1. Прочти вопрос пользователя.  
                2. Проверь, какие фрагменты базы связаны с этим вопросом.  
                3. На основе этих фрагментов сформулируй ответ.  
                4. Если фрагментов недостаточно — скажи: «Извините, но у меня нет достаточной информации в базе, чтобы ответить на этот вопрос».  
                5. Ответ должен быть на русском языке, понятным, профессиональным.  
                6. Обязательно укажи источники: название документа / файл / страница, откуда взят фрагмент.

                Пользовательский вопрос:  
                {question}

                Фрагменты контекста:  
                {context}

                Источники информации:
                {chr(10).join(f"• {source}" for source in sorted(sources))}"""

    answer = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}]
    )

    return answer.choices[0].message.content

# %%
import yaml

# Read questions from YAML file
yaml_path = 'benchmark.yaml'  # File is in same directory as notebook
with open(yaml_path, 'r', encoding='utf-8') as file:
    benchmark_data = yaml.safe_load(file)

questions = [q['question'] for q in benchmark_data['questions']]
answers = [q['answer'] for q in benchmark_data['questions']]

# %%
import datetime
import json

def ai_judge(question, ai_answer, correct_answer):
    """
    Оценивает качество ответа ИИ на ветеринарный вопрос с помощью экспертной модели.
    
    Функция использует GPT-4o-mini в качестве судьи для сравнения ответа ИИ с эталонным ответом.
    Оценка производится по критериям фактической точности, полноты, соответствия медицинской
    терминологии и практической применимости.
    
    Args:
        question (str): Исходный ветеринарный вопрос
        ai_answer (str): Ответ, сгенерированный ИИ-системой
        correct_answer (str): Эталонный (правильный) ответ для сравнения
        
    Returns:
        str: JSON-строка с результатом оценки в одной из категорий:
             - "Correct" - ответ полностью или в основном соответствует эталону
             - "Partially correct" - ответ содержит верную информацию, но неполный 
               или имеет незначительные неточности
             - "Incorrect" - ответ содержит существенные ошибки или не соответствует эталону
             
    Example:
        >>> result = ai_judge("Что такое лептоспироз?", "Инфекционная болезнь...", "Правильный ответ")
        >>> print(result)
        '{"result":"Correct"}'
    """
    
    comparison_prompt = f"""Ты - эксперт по ветеринарии. Твоя задача - оценить качество ответа искусственного интеллекта на ветеринарный вопрос.

    Вопрос: {question}

    Ответ ИИ: {ai_answer}

    Эталонный ответ (правильный): {correct_answer}

    Проанализируй ответ ИИ и сравни его с эталонным ответом. Учитывай:
    - Фактическую точность информации
    - Полноту ответа
    - Соответствие медицинской терминологии
    - Практическую применимость

    Дай оценку по одной из трех категорий:
    1. Correct - ответ полностью или в основном соответствует эталону
    2. Partially correct - ответ содержит верную информацию, но неполный или имеет незначительные неточности
    3. Incorrect - ответ содержит существенные ошибки или не соответствует эталону
    """

    from pydantic import BaseModel, Field
    
    class EvaluationResult(BaseModel):
        result: str = Field(description="Result in format 'Correct/Partially correct/Incorrect'")
    
    comparison = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": comparison_prompt}],
        response_format=EvaluationResult
    )
    
    return comparison.choices[0].message.content

# %%
def log_question_and_answers(question, ai_answer, correct_answer, correctness):
    print("\n📝 Вопрос:", question)
    print(f"🔍 Ответ модели: {ai_answer}")
    print(f"🔍 Правильный ответ: {correct_answer}")

    # Логирование в файл
    log_entry = {
        "timestamp": datetime.datetime.now().isoformat(),
        "question": question,
        "ai_answer": ai_answer,
        "correct_answer": correct_answer,
        "correctness": correctness
    }
    
    with open("benchmark_log.json", "a", encoding="utf-8") as log_file:
        log_file.write(json.dumps(log_entry, ensure_ascii=False) + "\n")

def evaluate_answers():
    correct_count = 0
    partially_correct_count = 0
    incorrect_count = 0
    
    for question, answer in zip(questions, answers):
        ai_answer, correct_answer = ask_qdrant(question), answer

        correctness = ai_judge(question, ai_answer, correct_answer)
        log_question_and_answers(question, ai_answer, correct_answer, correctness)
        
        # Подсчёт результатов
        if "Correct" in correctness and "Partially" not in correctness:
            correct_count += 1
        elif "Partially correct" in correctness:
            partially_correct_count += 1
        else:
            incorrect_count += 1
    
    # Вывод итоговой статистики
    total = correct_count + partially_correct_count + incorrect_count
    print(f"\n📊 Итоговая статистика:")
    print(f"✅ Правильных ответов: {correct_count} ({correct_count/total*100:.1f}%)")
    print(f"🟡 Частично правильных: {partially_correct_count} ({partially_correct_count/total*100:.1f}%)")
    print(f"❌ Неправильных ответов: {incorrect_count} ({incorrect_count/total*100:.1f}%)")
    print(f"📈 Общая точность: {(correct_count + partially_correct_count*0.5)/total*100:.1f}%")
    
    # Логирование итоговой статистики в файл
    summary_log = {
        "timestamp": datetime.datetime.now().isoformat(),
        "summary": {
            "correct_count": correct_count,
            "partially_correct_count": partially_correct_count,
            "incorrect_count": incorrect_count,
            "total": total,
            "correct_percentage": correct_count/total*100,
            "partially_correct_percentage": partially_correct_count/total*100,
            "incorrect_percentage": incorrect_count/total*100,
            "overall_accuracy": (correct_count + partially_correct_count*0.5)/total*100
        }
    }
    
    with open("benchmark_log.json", "a", encoding="utf-8") as log_file:
        log_file.write(json.dumps(summary_log, ensure_ascii=False) + "\n")

# Run evaluation
evaluate_answers()
# Out:
# 📝 Вопрос: Какие основные симптомы ящура у крупного рогатого скота?
# 🔍 Ответ модели: Основные симптомы ящура у крупного рогатого скота включают:
#
# 1. **Повышение температуры тела** до 40,5-42,0°C.
# 2. **Угнетение и слабость**.
# 3. **Отказ от корма** и прекращение жвачки.
# 4. **Повышенная саливация** и вовлечение слизистой оболочки рта.
# 5. На слизистой оболочке ротовой полости появляются **образования** в виде волдырей (афт), а также эрозии и язвы после разрыва афт.
# 6. **Обильное пенистое слюнотечение**.
# 7. Возможное развитие **конъюнктивита и вагинита**.
# 8. У больных животных отмечают снижение молочной продуктивности и болезненность при доении [1, 2, 3].
#
# Эти симптомы развиваются после инкубационного периода, который составляет от 3 до 17 дней, в зависимости от способа заражения [8].
#
# Источники:
# - SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 355, 371, 386)
# 🔍 Правильный ответ: Ящур характеризуется лихорадкой, слюнотечением, образованием везикул (пузырьков) на слизистой оболочке ротовой полости, на коже венчика и в межкопытной щели, хромотой.
#
# 📝 Вопрос: Что вызывает энзоотический лейкоз крупного рогатого скота и каковы его основные проявления?
# 🔍 Ответ модели: Энзоотический лейкоз крупного рогатого скота является злокачественным лимфопролиферативным заболеванием, вызванным вирусом лейкоза крупного рогатого скота (ВЛКРС). Этот вирус поражает, в первую очередь, B-лимфоциты и может вызывать у 30% инфицированных животных персистирующий лимфоцитоз, а у 0,1–10% — тяжелую патологию, включая лимфоидный лейкоз или лимфосаркомы.
#
# Основные проявления энзоотического лейкоза включают:
# - Увеличение поверхностных лимфатических узлов (околоушных, подчелюстных, надвыменных и др.).
# - Патологические изменения в органах, такие как увеличение печени и селезенки, а также дегенеративные изменения лимфатической системы.
# - Клинические признаки включают лихорадку, угнетение, слабость, снижение молочной продуктивности, жажду, прекращение жвачки и слизистые оболочки ротовой полости с серо-желтыми узелками.
#
# Уровень заболеваемости и симптомы зависят от специфических условий содержания животных, их возраста и устойчивости к инфекциям.
#
# Источники:
# 1. «Энзоотический лейкоз крупного рогатого скота» (стр. 258, 261)
# 2. «Лейкоз крупного рогатого скота» (стр. 207, 270)
# 🔍 Правильный ответ: Энзоотический лейкоз КРС вызывается вирусом лейкоза крупного рогатого скота (ВЛКРС). Основные проявления: персистентный лимфоцитоз, развитие лимфосарком в различных органах, увеличение лимфатических узлов.
#
# 📝 Вопрос: Каковы характерные симптомы вирусной диареи — болезни слизистых оболочек (BVDV) у крупного рогатого скота?
# 🔍 Ответ модели: Вирусная диарея — болезнь слизистых оболочек (ВД-БС) у крупного рогатого скота характеризуется следующими симптомами:
#
# 1. **Повышение температуры тела** до 41–42°C.
# 2. **Угнетение и слабость**.
# 3. **Жажда** и **прекращение жвачки**.
# 4. Наблюдается **увеличение поверхностных лимфатических узлов** (подчелюстных, околоушных).
# 5. На слизистых оболочках ротовой полости появляются серо-желтые узелки, которые при некрозе преобразуются в **эрозии и язвы**.
# 6. Обильное **покашливание** и выделение **пенистого слюнотечения**.
# 7. Возможны **конъюнктивит** и **вагинит** у коров.
# 8. В отдельных случаях может развиваться **геморрагическая диарея**, с фекалиями, содержащими кровь и кусочки слизистой оболочки кишечника.
#
# Заболевание обычно начинает проявляться постепенно и может привести к серьезным последствиям вплоть до гибели животного в течение 1–3 суток после появления первых клинических признаков. Смертность среди телят может достигать 60% (Источники: Глотов А.Г ., Глотова Т .И., Шуляк А.Ф. Ветеринария, 2012; 12: 3–6; Глотов А.Г ., Глотова Т .И. Ветеринария, 2015; 4: 3–8).
#
# Если вам нужна детальная информация по каждому симптому или другим аспектам болезни, пожалуйста, сообщите!
# 🔍 Правильный ответ: Симптомы BVDV включают диарею, эрозии и изъязвления на слизистых оболочках ротовой полости и пищеварительного тракта, лихорадку, угнетение, снижение продуктивности. У стельных коров может приводить к абортам и рождению телят с врожденными дефектами.
#
# 📝 Вопрос: Как проявляется инфекционный ринотрахеит / инфекционный пустулезный вульвовагинит у КРС?
# 🔍 Ответ модели: Инфекционный ринотрахеит (ИРТ) и инфекционный пустулезный вульвовагинит (ИПВ) у крупного рогатого скота (КРС) проявляются следующими клиническими признаками:
#
# 1. **Инфекционный ринотрахеит (ИРТ)**:
#    - Заболевание вызывает острое воспаление дыхательных путей.
#    - Симптомы включают лихорадку, конъюнктивит, носовые истечения, кашель.
#    - При тяжёлых формах возможны пневмония и другие осложнения, приводящие к ухудшению состояния животных.
#
# 2. **Инфекционный пустулезный вульвовагинит (ИПВ)**:
#    - У коров наблюдаются признаки лихорадки, депрессии, анорексии и боли при мочеиспускании.
#    - Внешние половые органы (вульва и влагалище) отекают, становятся покрасневшими, покрыты пустулами, которые могут сливаться и образовывать язвы.
#    - Острое течение болезни продолжается 4–5 дней, после чего при отсутствии осложнений клинические проявления могут полностью исчезнуть через 10–14 дней.
#    - Часто заболевание протекает в субклинической форме и может оставаться незамеченным [фрагменты из документов: 277, 280, 388].
#
# Эти заболевания вызваны герпесвирусом 1 типа крупного рогатого скота и представляют собой значительную проблему для молочного и мясного животноводства [фрагмент 277].
# 🔍 Правильный ответ: Инфекционный ринотрахеит проявляется лихорадкой, депрессией, серозными, а затем гнойными истечениями из носа, кашлем, конъюнктивитом. При генитальной форме — вульвовагинит с образованием пустул и язв на слизистой оболочке влагалища и вестибулярной части полового члена быков.
#
# 📝 Вопрос: Что такое блютанг и какие симптомы ему свойственны?
# 🔍 Ответ модели: Блютанг — это вирусная инфекция, которая поражает в первую очередь овец и крупный рогатый скот. Симптомы блютанга варьируются в зависимости от вида и возраста животных, а также от штамма вируса. Основные клинические признаки включают:
#
# 1. **Лихорадка** — внезапное повышение температуры тела.
# 2. **Гиперемия слизистых оболочек** — покраснение и отечность слизистой оболочки рта и носа.
# 3. **Нарушения в развитии плода** у суягных и стельных животных — возможна мумификация плода.
# 4. **Патогномоничные изменения** — изъязвления и некрозы на слизистой рта, глаз, а также отеки в области головы, шеи и грудной клетки.
# 5. **Кровоизлияния** — появляются мелкоточечные кровоизлияния на слизистых оболочках, также могут наблюдаться гематомы.
# 6. **Хромота и выпадение шерсти** — отечность конечностей может привести к хромоте, животные могут терять шерсть.
#
# Другие симптомы могут включать истечение из носовой полости и общую слабость, а также увеличение объема желудка у жвачных животных. Заболевание чаще протекает в острой форме и может быть фатальным, особенно у высокопородных овец [415][413][414][416].
#
# Источники:
# - SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 415, 414, 413, 416)
# 🔍 Правильный ответ: Блютанг (катаральная лихорадка) — вирусное заболевание, передающееся мокрецами. Симптомы: лихорадка, гиперемия и цианоз слизистых оболочек, отек языка, губ, лица, хромота из-за поражения венчика коронарного края, язвенный стоматит.
#
# 📝 Вопрос: Что такое габитус животного?
# 🔍 Ответ модели: Габитус животного — это наружный вид животного в период исследования, определяемый по совокупности внешних признаков. Он характеризует положение тела в пространстве, телосложение, упитанность, конституцию и темперамент. Положение тела может быть нормальным, вынужденным или ненормальным. Например, типичные признаки заболеваний, сопровождающихся ненормальным положением тела, включают вытянутое положение головы при фарингите или столбняке у лошади. Телосложение оценивается по развитию скелета и мышц, а упитанность определяется осмотром, пальпацией и взвешиванием животного.
#
# Источник: SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 101).
# 🔍 Правильный ответ: Габитус — это наружный вид животного в период исследования, определяемый по совокупности внешних признаков, характеризующих положение тела в пространстве, телосложение, упитанность, конституцию, темперамент.
#
# 📝 Вопрос: При каких заболеваниях складка кожи или не расправляется, или расправляется медленно?
# 🔍 Ответ модели: Складка кожи может не расправляться или расправляться медленно при общем снижении эластичности кожи, что часто бывает при различных заболеваниях. Такой симптом может наблюдаться также при местных заболеваниях кожи, таких как чесотка, хроническая экзема, дерматит и других воспалительных процессах на коже.
#
# Снижение эластичности кожи, при котором складка не расправляется или расправляется медленно, указывает на наличие патологических изменений в организме, которые могут быть вызваны различными заболеваниями или состояниями, такими как интоксикации или старение.
#
# Источники:
# - SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 30)
# - SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 226)
# 🔍 Правильный ответ: Такой симптом наблюдается при общей потере или снижении эластичности кожи, а также при местных заболеваниях кожи (чесотке, хронической экземе, дерматите и др.).
#
# 📝 Вопрос: Какие основные дыхательные шумы выделяют при аускультации легких?
# 🔍 Ответ модели: При аускультации легких выделяют основные дыхательные шумы, среди которых можно выделить следующие:
#
# 1. **Гортанный шум сужения** — возникает при движении воздуха в верхних отделах дыхательной системы, таких как ноздри, носовые ходы и голосовая щель. Этот звук напоминает "х" и усиливается при значительном расширении гортани.
#
# 2. **Везикулярное дыхание** — представляет собой мягкий звук, возникающий при движении воздуха из бронхиол в альвеолы. У здоровых животных оно звучит как мягкое "ф", и его сила может варьироваться у разных видов животных.
#
# 3. **Бронхиальное дыхание** — слышится у всех домашних животных в определенных областях грудной клетки, но у лошадей может указывать на патологии.
#
# 4. **Амфорическое дыхание** — является измененной формой бронхиального дыхания, отличается глубиной и мягкостью, напоминает звук вдыхаемого воздуха в бутылку и обнаруживается над большими кавернами в легких.
#
# 5. **Смешанное дыхание** — комбинирует свойства везикулярного и бронхиального дыханий.
#
# Эти шумы дают важную информацию о состоянии легких и плевры животных при диагностике патологиям. (Источник: SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf, стр. 59)
# 🔍 Правильный ответ: К основным дыхательным шумам относятся: гортанный шум сужения, везикулярное, бронхиальное, амфорическое и смешанное дыхание.
#
# 📝 Вопрос: Что такое punctum optimum сердечных тонов?
# 🔍 Ответ модели: Punctum optimum сердечных тонов — это точки на поверхности тела, в которых сердечные тоны лучше воспринимаются при аускультации сердца. Это связано с тем, что каждый компонент сердечного тона имеет свою собственную точку максимальной слышимости, где звук наиболее четкий и выразительный. Исследование этих пунктов является важным при определении места возникновения патологических звуков, выявленных во время аускультации.
#
# Например, у лошади punctum optimum двустворчатого клапана находится в V левом межреберном промежутке, на уровне середины нижней трети грудной клетки. Punctum optimum трехстворчатого клапана располагается в III–IV правом межреберном промежутке, а точка максимальной слышимости легочной артерии можно найти в III левом межреберном промежутке, под линией, делящей пополам нижнюю треть грудной клетки. Для крупных рогатых скотов эти точки совпадают с лошадьми, за исключением punctum optimum двустворчатого клапана, который находится в IV левом межреберном промежутке (SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf, стр. 65).
#
# Чтобы правильно оценить сердечные тоны и их происхождение, важно знать не только местоположение этих точек, но и то, как они могут варьироваться в зависимости от состояния здоровья животного.
# 🔍 Правильный ответ: Punctum optimum — это точки наилучшей слышимости сердечных тонов, соответствующие местам возникновения отдельных компонентов тонов сердца.
#
# 📝 Вопрос: Какие методы относятся к графическим исследованиям сердечно-сосудистой системы?
# 🔍 Ответ модели: К графическим методам исследования сердечно-сосудистой системы относятся:
#
# 1. **Электрокардиография** — метод, основанный на регистрации электрических сигналов, возникающих в сердце во время его работы. Эти сигналы фиксируются специальным прибором — электрокардиографом, что позволяет судить о состоянии сердца и его проводящей системе.
#
# 2. **Сфигмография** — метод, который используется для объективной оценки качества пульса. Он осуществляется с использованием сфигмотонометра и портативного артериального осциллографа, позволяющих записывать пульсовые волны.
#
# 3. **Флебография** — метод, применяемый для исследование вен, хотя в данном фрагменте его описание не упоминается напрямую.
#
# Эти методы применяются в ветеринарной практике для диагностики различных заболеваний сердечно-сосудистой системы у животных (источник: SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf, стр. 72).
# 🔍 Правильный ответ: К графическим методам исследования сердечно-сосудистой системы относятся электрокардиография, сфигмография и флебография.
#
# 📝 Вопрос: При каких заболеваниях у крупного рогатого скота лимфатические узлы могут быть увеличенными, бугристыми, холодными и безболезненными?
# 🔍 Ответ модели: У крупного рогатого скота лимфатические узлы могут увеличиваться, становиться бугристыми, холодными и безболезненными при нескольких заболеваниях. Наиболее распространенные из них — лимфоидный лейкоз и лимфосаркома. Эти заболевания характеризуются системным поражением кроветворной и лимфоидной тканей с вовлечением костного мозга, селезенки и лимфатических узлов. При лимфоидном лейкозе, например, наблюдается увеличение поверхностных лимфатических узлов (подчелюстных, околоушных, надвыменных) и может возникать лимфоцитоз в крови.
#
# Также стоит учитывать, что при лимфогранулематозе и других нечастых формах, описанных в материалах, изменение состояния лимфатических узлов может происходить, однако это менее распространено.
#
# Источник: _2021.pdf (стр. 562), _2021.pdf (стр. 270).
# 🔍 Правильный ответ: Такие изменения лимфатических узлов наблюдаются при туберкулезе крупного рогатого скота.
#
# 📝 Вопрос: Что такое этиотропная терапия?
# 🔍 Ответ модели: Этиотропная терапия (или причинная терапия) — это метод лечения, целью которого является устранение причины заболевания у животных. Эта форма терапии применяется, когда этиологический фактор продолжает отрицательно воздействовать на организм. Причинами могут быть различного рода факторы, такие как неправильные условия содержания и кормления, опасные возбудители болезней, токсины и инородные тела.
#
# К основным средствам, используемым в этиотропной терапии, относятся:
# - противомикробные препараты,
# - специфические гипериммунные сыворотки,
# - иммуноглобулины,
# - анароксины,
# - бактериофаги,
# - пробиотики,
# - антидоты при отравлениях,
# - противогельминтные и другие противопаразитарные препараты,
# - хирургические операции по удалению инородных тел.
#
# Этиотропная терапия может быть использована для лечения различных заболеваний, таких как желудочно-кишечные, сердечно-сосудистые, болезни мочевой системы и нервной системы, среди прочих.
#
# Источники:
# - SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 135, 136, 137, 138)
# 🔍 Правильный ответ: Этиотропная (причинная) терапия направлена на устранение причины болезней. Ее применяют, если этиологический фактор продолжает неблагополучно воздействовать на организм животного.
#
# 📝 Вопрос: Каковы нормальные показатели температуры тела у здоровой взрослой кошки?
# 🔍 Ответ модели: Нормальная температура тела у взрослой здоровой кошки колеблется в пределах 38,0 – 39,5 градусов Цельсия. Эта информация является важным показателем здоровья и позволяет выявить возможные заболевания животного.
#
# Источник: SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 26).
# 🔍 Правильный ответ: 38,0 – 39,5 °C
#
# 📝 Вопрос: Что такое симптоматическая терапия?
# 🔍 Ответ модели: Симптоматическая терапия — это применение средств, направленных на устранение или ослабление наиболее угрожающих жизни животного симптомов болезни. Примеры симптоматической терапии включают назначение жаропонижающих препаратов при высокой температуре, использование вяжущих средств при диарее, когда обезвоживание угрожает жизни, или противокашлевых средств, если кашель вызывает кислородное голодание. Симптоматическая терапия всегда проводится в комплексе с этиотропной и патогенетической терапиями, так как ликвидация симптомов не является показателем выздоровления. Иногда она рассматривается как часть патогенетической терапии, поскольку воздействие на симптом может быть направлено на какое-либо звено патогенеза болезни (источник: SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf, стр. 136).
# 🔍 Правильный ответ: Симптоматическая терапия – это использование средств, направленных на ликвидацию или ослабление наиболее угрожающих жизни животного симптомов болезни.
#
# 📝 Вопрос: Каковы основные пути передачи возбудителя ящура?
# 🔍 Ответ модели: Возбудитель ящура может передаваться несколькими основными путями:
#
# 1. **Контактный путь**: Передача осуществляется при прямом контакте между больными и здоровыми животными, а также через предметы ухода, инвентарь (лопаты, ведра и т. д.), корма, подстилку и продукты животного происхождения (молоко, мясо и т.д.) [34, 41].
#
# 2. **Воздушный путь**: Возбудитель может распространяться через аэрозоли, что позволяет ему перемещаться на значительные расстояния (до 60 км над сушей и до 300 км над водной поверхностью). Этот путь передачи зависит от метеорологических условий и может осуществляться при чихании, кашле и других выделениях больного животного [34, 41].
#
# 3. **Алиментарный путь**: Вирус может передаваться через загрязненные корма и воду, что является характерным для свиней, которые наиболее подвержены алиментарному заражению в результате скармливания несоответствующих кормов [41].
#
# 4. **Трансмиссивный путь**: Этот путь передачи осуществляется через живых переносчиков, таких как вши, клещи, комары и блохи [34, 41].
#
# 5. **Вертикальный путь**: Передача возможна от родителей к потомству через молоко, плаценту или яйца [34, 41].
#
# Таким образом, ящур демонстрирует разнообразие путей передачи, что увеличивает риск его распространения среди животноводческих ферм.
#
# **Источники:**
# - _2021.pdf (стр. 249)
# - _2021.pdf (стр. 254)
# - oie_terrestrial_code_vol-1-2021_ru.pdf (стр. 94)
# - oie_terrestrial_code_vol-1-2021_ru.pdf (стр. 103)
# 🔍 Правильный ответ: Заражение чаще всего происходит при прямом контакте больных и здоровых животных. Передача возбудителя возможна через корм, воду, подстилку, предметы ухода, а также через продукты и сырье животного происхождения. Переносчиком могут быть животные и птица, которые ящуром обычно не болеют, а также люди.
#
# 📝 Вопрос: Какие дезинфицирующие средства рекомендуются для дезинфекции при туберкулезе?
# 🔍 Ответ модели: Для дезинфекции при туберкулезе рекомендуются следующие дезинфицирующие средства:
#
# 1. **Смесь 3%-ного раствора едкого натра и 3%-ного раствора формальдегида** в соотношении 1:1.
# 2. **10%-ный горячий раствор серно-карболовой смеси**.
# 3. **Растворы хлорной извести** с содержанием не менее 5% активного хлора.
# 4. **3%-ный раствор формальдегида**.
# 5. **Глутаровый альдегид** в концентрации 2%.
# 6. **0,5%-ный раствор формальдегида** для обработки помещений и оборудования.
#
# Эти средства необходимо применять с учетом техники безопасности и правил применения, так как некоторые из них могут быть агрессивными для тканей и опасными при попадании на кожу или в органы дыхания. При дезинфекции также рекомендуется соблюдать рекомендации по времени воздействия дезинфицирующих средств и их концентрации (например, 0,5 л на м² при дезинфекции).
#
# Источники:
# - SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf (стр. 285, 449, 460)
# - _2021.pdf (стр. 611, 574, 728)
# 🔍 Правильный ответ: Для дезинфекции применяют 10 %-ный горячий раствор серно-карболовой смеси, осветленный раствор хлорной извести, содержащий не менее 5 %-ного активного хлора, раствор с содержанием 3 %-ного формальдегида и 3 %-ной гидроокиси натрия, трехкратную побелку помещений 20 %-ной взвесью свежегашеной извести.
#
# 📝 Вопрос: Каков инкубационный период при сибирской язве?
# 🔍 Ответ модели: Инкубационный период сибирской язвы обычно составляет от 1 до 3 суток, однако в отдельных случаях он может удлиняться до 14 суток. При быстротечном течении болезни смерть животного может наступить в течение 1-3 часов после появления первых симптомов. Это особенно характерно для хорошо упитанных животных, которые могут внезапно падать без предварительных признаков болезни, с выделением кровянистой пены из рта и носа.
#
# Источник: spravochnikveterinarnogospecialistaaahannikov.pdf (стр. 29).
# 🔍 Правильный ответ: Инкубационный период сибирской язвы длится 1–3 суток, иногда до 14 суток.
#
# 📝 Вопрос: Каковы основные клинические признаки отечной болезни поросят?
# 🔍 Ответ модели: Основные клинические признаки отечной болезни поросят включают:
#
# 1. Острое повышение температуры тела до 40,1–41,1 градуса Цельсия, которое держится в течение двух-трех дней, а затем может снизиться до нормы.
# 2. Угнетенное состояние поросят, отсутствие аппетита.
# 3. Характерная шаткость походки и кратковременный понос.
# 4. Явные отеки век, что может приводить к закрытию глазной щели, из-за сильного отека конъюнктивы.
# 5. Отеки могут также отмечаться в области носа, пятачка, затылка и спины.
# 6. У некоторых поросят наблюдается отек гортани, что вызывает хрипоту и полную потерю голоса.
# 7. В предсмертный период развиваются парезы и параличи конечностей, признаки удушья, снижение температуры тела, еле ощутимый пульс, и частота сердечных сокращений может достигать 170–200 ударов в минуту.
# 8. Продолжительность болезни обычно составляет от 1 до 4 дней.
#
# Диагноз ставится на основе клинических признаков, учитывая, что около 40% случаев могут протекать без выраженных отеков (SHerbakov_G.G._Kovalev_S._P._YAshin_A.V._Vinnib-ok.org_.pdf, стр. 187).
# 🔍 Правильный ответ: Кратковременное повышение температуры тела до 40,1 – 41,1 °C, угнетение, отсутствие аппетита, шаткая походка, кратковременный понос, жажда, отек век и конъюнктивиты, отеки в области носа, пятачка, затылка, спины, гортани (что приводит к хрипоте), парезы и параличи конечностей, признаки удушья.
#
# 📝 Вопрос: Что такое 'списочная болезнь' согласно Кодексу здоровья наземных животных МЭБ?
# 🔍 Ответ модели: Согласно Кодексу здоровья наземных животных МЭБ, 'списочная болезнь' — это болезнь, инфекция или инфестация, которая включена в главу 1.3 после утверждения Всемирной ассамблеей Делегатов. Включение болезней основано на определённых критериях, включая их влияние на здоровье животных и потенциальные риски для здоровья человека. Эти списочные болезни включают различные заболевания, которые имеют значительное значение для ветеринарной общественности и торговли животными.
#
# Извините, но у меня нет достаточной информации в базе, чтобы ответить на этот вопрос более подробно.
#
# Источники:
# - Кодекс здоровья наземных животных МЭБ 2021 г., Глава 1.3, стр. 9.
# 🔍 Правильный ответ: Это болезнь, инфекция или инфестация, включённая в специальный перечень после утверждения Всемирной ассамблеей Делегатов МЭБ.
#
# 📝 Вопрос: Каковы цели надзора за здоровьем животных?
# 🔍 Ответ модели: Цели надзора за здоровьем животных включают следующее:
#
# 1. **Доказательство отсутствия инфекции или инфестации**: Надзор направлен на подтверждение того, что определенные инфекции или паразиты отсутствуют в популяциях животных.
#
# 2. **Определение присутствия и превалентности инфекций**: Он также служит для выявления и оценки уровня распространенности различных инфекционных заболеваний.
#
# 3. **Раннее выявление экзотических или эмерджентных болезней**: Важной целью является максимальное раннее обнаружение новых или непредвиденных болезней, которые могут представлять угрозу для здоровья животных и людей.
#
# 4. **Отслеживание эволюции инфекций**: Этот инструмент помогает в мониторинге изменений в динамике заболеваний, что облегчает их контроль.
#
# 5. **Сбор данных для анализа рисков**: Надзор предоставляет важную информацию, которая необходима для оценки рисков и принятия решений, направленных на защиту здоровья животных и людей.
#
# 6. **Обоснование ветеринарно-санитарных мер**: Собранные данные могут служить основой для разработки и обоснования государственных и международных ветеринарных санитарных мероприятий.
#
# 7. **Гарантия торговым партнерам**: Надзор обеспечивает надежность and безопасность здоровья животных, что способствует международной торговле.
#
# Тип проводимого надзора зависит от целей и доступных данных, что позволяет адаптировать подходы к конкретным условиям и требованиям (Кодекс здоровья наземных животных МЭБ 2021 г., глава 1.4).
# 🔍 Правильный ответ: Целями надзора являются доказательство отсутствия инфекции или инфестации, определение их присутствия или распространённости, или максимально раннее выявление новых или экзотических болезней.
#
# 📝 Вопрос: Что такое 'безрисковый товар'?
# 🔍 Ответ модели: Безрисковый товар в контексте международной торговли — это животный продукт, который соответствует определённым критериям безопасности и не содержит патогенных агентов, способных вызвать инфекцию у человека или других животных. В частности, для признания товара безрисковым, требуется:
#
# 1) Наличие весомых оснований для утверждения, что патогенные агенты отсутствуют в тканях, из которых выработан продукт, в количествах, способных вызвать инфекцию.
# 2) В случае потенциального присутствия патогенных агентов необходимо, чтобы они были инактивированы в процессе переработки или обработки.
#
# Эти определения и требования направлены на защиту здоровья человека и животных и установлены в Кодексе здоровья наземных животных МЭБ 2021 года (Статья 2.2.1).
#
# Источники:
# - oie_terrestrial_code_vol-1-2021_ru.pdf (стр. 10)
# - oie_terrestrial_code_vol-1-2021_ru.pdf (стр. 162)
# 🔍 Правильный ответ: Это товар, который может выступать предметом торговли без необходимости принятия особых мер для снижения риска по одной из списочных болезней, вне зависимости от статуса страны или зоны его происхождения.
#
# 📝 Вопрос: Каковы критерии включения болезни в Список МЭБ?
# 🔍 Ответ модели: Болезни, инфекции и инфестации могут быть включены в Список Международной эпизоотической бюро (МЭБ) на основании следующих критериев:
#
# 1. **Международное распространение** патогенного агента (через живых животных, продукцию животного происхождения, переносчиков или контаминированные предметы).
#
# 2. Наличие хотя бы одной страны, которая доказала отсутствие болезни, инфекции или инфестации в популяциях восприимчивых животных.
#
# 3. Наличие надежных методов выявления и диагностики, а также четкого определения случаев, позволяющего безусловно идентифицировать случаи и отличать их от других болезней.
#
# 4. Значительность урона, наносимого заболеванием диким животным, на основании частоты и степени клинических признаков, включая экономические потери и падеж.
#
# Эти критерии обеспечивают системный подход к включению болезней в этот список, исходя из доказательной базы и влияния на здоровье животных и экономическую стабильность.
#
# (Источник: Кодекс здоровья наземных животных МЭБ 2021 г., Глава 1.2, стр. 4 и 5.)
# 🔍 Правильный ответ: Международное распространение патогенного агента; доказанное отсутствие болезни хотя бы в одной стране; надёжные методы диагностики; значительное влияние на здоровье животных или людей.
#
# 📝 Вопрос: Что такое 'официальная программа контроля'?
# 🔍 Ответ модели: Официальная программа контроля — это программа, утверждённая, проводимая или контролируемая Ветеринарным органом страны с целью борьбы с переносчиками, патогенными агентами или болезнями путём принятия специальных мер. Важнейшими составляющими такой программы являются план контроля или ликвидации инфекции, соответствующее ветеринарное законодательство, планы подготовки к чрезвычайным ситуациям, надзор за инфекцией, регулярное нотифицирование болезней животных, а также меры по выявлению и ликвидации случаев инфекции с целью ограничения её распространения и минимизации трансмиссии.
#
# При планировании официальных программ контроля необходимо учитывать сложившиеся эпизоотические, экологические и социально-экономические условия, а также ставить конкретные задачи, на решение которых частный сектор не имеет достаточных средств (источник: Кодекс здоровья наземных животных МЭБ 2021 г., стр. 18, 114, 119, 131).
# 🔍 Правильный ответ: Это программа, утверждённая, проводимая или контролируемая Ветеринарным органом страны для борьбы с переносчиками, патогенными агентами или болезнями.
#
# 📝 Вопрос: Как определяется 'благополучие животных'?
# 🔍 Ответ модели: Благополучие животных — это физическое и ментальное состояние животного, которое определяется условиями его жизни и смерти. Критерии, подтверждающие хорошее благополучие, включают хорошее состояние здоровья, комфортные условия содержания, адекватное питание и безопасность. Животное не должно испытывать боль, страх или угнетённость и должно иметь возможность проявлять своё естественное поведение.
#
# Элементы благополучия животных включают:
# - Профилактику заболеваний.
# - Надлежащий ветеринарный уход.
# - Укрытие.
# - Управление содержанием.
# - Удовлетворительное кормление.
# - Безопасную и благоприятную окружающую среду.
# - Гуманное обращение, включая гуманные условия убоя и умерщвления.
#
# Индикаторами, которые помогают определить уровень угрозы благополучию животных, являются так называемые "пять свобод":
# 1. Свобода от голода и жажды.
# 2. Свобода от дискомфорта.
# 3. Свобода от боли, увечий и болезней.
# 4. Свобода от страха и стресса.
# 5. Свобода естественного поведения.
#
# Существуют также научные методы оценки благополучия животных, которые учитывают различные параметры и показатели, такие как здоровье, поведение, физическое состояние и реакция животных на обращения (Кодекс здоровья наземных животных МЭБ 2021 г., Статья 7.1.1; статья 7.1.2).
#
# Источники информации:
# - oie_terrestrial_code_vol-1-2021_ru.pdf (стр. 12, 161, 382, 383, 384, 493, 498)
# 🔍 Правильный ответ: Это физическое и ментальное состояние животного в связи с условиями его жизни и смерти.
#
# 📝 Вопрос: Что понимается под термином 'эпизоотическая единица'?
# 🔍 Ответ модели: Под термином "эпизоотическая единица" понимается группа животных, которые с равной вероятностью подвергаются риску воздействия патогенного агента. Эта единица может состоять из отдельных особей или небольших групп животных, находящихся в одной среде обитания или относящихся к единой системе хозяйствования, как например стадо или поголовье. В некоторых случаях эпизоотическую единицу может составлять и одно животное.
#
# Кроме того, для целей надзора единица выборки в обследованиях должна определяться с учётом принятой эпизоотической единицы (Кодекс здоровья наземных животных МЭБ, 2021 г., стр. 258, 367).
#
# Эти определения помогают в организации надзора и контроля за распространением инфекционных заболеваний среди животных, что является важной частью ветеринарной практики.
#
# Источники:
# - Кодекс здоровья наземных животных МЭБ 2021 г. (стр. 258, 367).
# 🔍 Правильный ответ: Группа животных, с равной вероятностью подвергающихся риску воздействия патогенного агента.
#
# 📝 Вопрос: Какие существуют виды выборки при проведении надзорных мероприятий?
# 🔍 Ответ модели: При проведении надзорных мероприятий используются различные виды выборки, которые можно классифицировать в зависимости от стратегии отбора проб. Основные виды выборки включают:
#
# 1. **Вероятностная выборка** — стратегия, при которой каждая единица популяции имеет известную ненулевую вероятность быть включенной в выборку. Это обеспечивает репрезентативность данных.
#
# 2. **Методы, основанные на рисках** — фокусируются на отдельных субпопуляциях, где предполагается высокая вероятность заноса или выявления инфекции. Эти методы могут использовать как вероятностную, так и невероятностную выборку.
#
# 3. **Целевой надзор** — включает отбор проб из определённых групп, например, у животных, от которых получают пищевые продукты, контрольных животных и других.
#
# 4. **Анализ ветеринарной практики** — основан на собранной информации о результатах лабораторной диагностики.
#
# 5. **Серологический надзор** — исследование на наличие антител в крови у целевой популяции для оценки уровня заболевания.
#
# 6. **Передубойный и послеубойный осмотр** — позволяет получить данные о здоровье животных в определённых условиях.
#
# Каждая из этих стратегий должна учитывать специфику целевой популяции и цели надзора, обеспечивая репрезентативность и надежность результатов.
#
# Источники информации: Кодекс здоровья наземных животных МЭБ 2021 г., стр. 14, 15, 33, 34, 38, 53, 88, 91.
# 🔍 Правильный ответ: Вероятностная (случайная) выборка и невероятностная выборка, которые могут применяться separately или комбинироваться.
#
# 📝 Вопрос: Каковы основные требования к системе раннего оповещения о болезнях животных?
# 🔍 Ответ модели: Система раннего оповещения о болезнях животных является важным инструментом для своевременного выявления и информирования о возникновении инфекций и болезней, а также является частью подготовки к экстренным эпизоотическим ситуациям. Основные требования к такой системе включают:
#
# 1. **Свободный доступ Ветеринарной службы** к целевым популяциям животных и полномочия по отношению к ним.
# 2. **Доступ к лабораториям**, способным проводить диагностические исследования и дифференциальную диагностику для определённых инфекций.
# 3. **Программы обучения и информирования**, направленные на обязательное выявление и деклорацию необычных эпизоотических событий, которые должны быть адресованы ветеринарам, параветеринарам и владельцам животных.
# 4. **Эффективный надзор** для раннего выявления, отслеживания и декларации существующих и новых заболеваний, включая разработку обновляемого перечня болезней обязательной декларации.
# 5. **Использование официальных процедур самодекларации** и признания статуса благополучия по болезням в соответствии с требованиями международных стандартов.
#
# Эти требования направлены на создание чёткой и прозрачной системы, способствующей быстрой реакции на вспышки инфекционных заболеваний и управлению их последствиями (Кодекс здоровья наземных животных МЭБ 2021 г., Глава 1.1, Статья 1.4.5).
#
# Для эффективной работы системы необходим постоянный мониторинг и аудит её функционирования, а также подготовка ветеринарных специалистов и регулярные симуляции сценариев реагирования (Кодекс здоровья наземных животных МЭБ 2021 г., Статья 4.19.4).
# 🔍 Правильный ответ: Свободный доступ к животным, доступ к диагностическим лабораториям, обучение специалистов, обязательность декларации подозрений, проведение эпизоотических расследований.
#
# 📝 Вопрос: Какие категории болезней включены в Список МЭБ?
# 🔍 Ответ модели: Список заболеваний, инфекций и инфестаций, включенных в Кодекс здоровья наземных животных МЭБ, классифицирован на несколько категорий. Вот основные из них:
#
# 1. **Болезни, инфекции и инфестации нескольких видов животных**:
#    - блютанг
#    - восточный инфекционный энцефаломиелит лошадей
#    - гидроперикардит
#    - западнонильская лихорадка
#    - инфекция вирусом геморрагической эпизоотической болезни
#    - инфекция вирусом бешенства
#    - инфекция вирусом болезни Ауески
#    - инфекция Echinococcus granulosus
#    - инфекция Echinococcus multilocularis
#    - инфекция Trichinella spp.
#    - инфекция комплексом Mycobacterium tuberculosis
#    - инфекция ящурным вирусом
#
# 2. **Болезни и инфекции крупного рогатого скота**:
#    - анаплазмоз крупного рогатого скота
#    - бабезиоз крупного рогатого скота
#    - вирусная диарея крупного рогатого скота
#    - губкообразная энцефалопатия и другие.
#
# 3. **Болезни и инфекции овец и коз**:
#    - инфекционная агалактия овец и коз
#    - артрит/энцефалит коз и другие.
#
# 4. **Болезни и инфекции свиней**:
#    - вирусный энцефалит Нипах
#    - инфекция вирусом африканской чумы свиней и другие.
#
# 5. **Болезни и инфекции птиц**:
#    - инфекционный бронхит птиц
#    - инфекционный бурсит (болезнь Гамборо) и другие.
#
# 6. **Прочие болезни и инфекции**:
#    - верблюжья оспа
#    - инфекция дромадер коронавирусом ближневосточного респираторного синдрома
#    - лейшманиоз и другие.
#
# Данный список включает только некоторые примеры и не является полным.
#
# (Источники: Кодекс здоровья наземных животных МЭБ 2021 г., Глава 1.3.)
# 🔍 Правильный ответ: Болезни нескольких видов животных, болезни КРС, овец и коз, непарнокопытных, свиней, птиц, кроликов, пчел и другие болезни.
#
# 📝 Вопрос: Что такое 'защитная зона' согласно Кодексу?
# 🔍 Ответ модели: Согласно Кодексу здоровья наземных животных МЭБ, 'защитная зона' — это зона, в которой действует особый режим биологической безопасности и ветеринарно-санитарные меры. Эти меры направлены на предупреждение заноса патогенных агентов в благополучную страну или зону из сопредельной страны или зоны с иным ветеринарным статусом. Защитная зона может быть установлена временно в ответ на повышенный риск заболевания и может действовать не более 24 месяцев.
#
# Кроме того, защитная зона может быть создана как внутри, так и за пределами благополучной зоны или страны. В ней действуют меры биобезопасности, которые зависят от системы управления животными, эпизоотологии болезни и ситуации в сопредельных заражённых зонах. Меры должны включать контроль перемещений, идентификацию животных и прослеживание (источник: Кодекс здоровья наземных животных МЭБ 2021 г., страницы 12, 13, 14).
# 🔍 Правильный ответ: Зона, в которой действует особый режим биобезопасности и ветеринарно-санитарные меры для предупреждения заноса патогенного агента.
#
# 📊 Итоговая статистика:
# ✅ Правильных ответов: 16 (55.2%)
# 🟡 Частично правильных: 13 (44.8%)
# ❌ Неправильных ответов: 0 (0.0%)
# 📈 Общая точность: 77.6%
